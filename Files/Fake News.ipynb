# %%
# %run functions.ipynb
import json

# %% [markdown]
# # CREDBANK Processing

# %%
cred_Processing(r"C:\Users\eric4\Desktop\University\Research\Data\CREDBANK\cred_event_SearchTweets.data")
# Out:
# host_patrick_neil-20141015_161647-20141015_172214
# royals_game_series-20141015_203526-20141015_213926
# giants_game_win-20141015_230140-20141016_000502
# october_ebola_house-20141015_230140-20141016_000502
# ebola_white_health-20141016_012559-20141016_030253
# oscar_pistorius_because-20141016_044421-20141016_060856
# news_breaking_ebola-20141016_072313-20141016_082727
# artist_vote_year-20141016_111453-20141016_121002
# kobe_espn_ranked-20141016_111453-20141016_121002
# story_october_ebola-20141016_111453-20141016_121002
# ebola_obama_#ebola-20141016_181953-20141016_192544
# game_brady_jets-20141016_181953-20141016_192544
# year_artist_#amas-20141016_203448-20141016_213927
# #oscartrial_roux_him-20141017_021821-20141017_040749
# breaking_news_dead-20141017_054732-20141017_070826
# west_india_indies-20141017_054732-20141017_070826
# ebola_health_board-20141017_081818-20141017_092258
# ebola_obama_night-20141017_081818-20141017_092258
# ...

# %%
tweetsMap = {}
count = 0
with open(r"C:\Users\eric4\Desktop\University\Research\Data\CREDBANK\outputTweets.json", "r") as f:
    for line in f:
        tweetData = json.loads(line)
        print(tweetData["key"])
# Out:
# host_patrick_neil-20141015_161647-20141015_172214
# royals_game_series-20141015_203526-20141015_213926
# giants_game_win-20141015_230140-20141016_000502
# october_ebola_house-20141015_230140-20141016_000502
# ebola_white_health-20141016_012559-20141016_030253
# oscar_pistorius_because-20141016_044421-20141016_060856
# news_breaking_ebola-20141016_072313-20141016_082727
# artist_vote_year-20141016_111453-20141016_121002
# kobe_espn_ranked-20141016_111453-20141016_121002
# story_october_ebola-20141016_111453-20141016_121002
# ebola_obama_#ebola-20141016_181953-20141016_192544
# game_brady_jets-20141016_181953-20141016_192544
# year_artist_#amas-20141016_203448-20141016_213927
# #oscartrial_roux_him-20141017_021821-20141017_040749
# breaking_news_dead-20141017_054732-20141017_070826
# west_india_indies-20141017_054732-20141017_070826
# ebola_health_board-20141017_081818-20141017_092258
# ebola_obama_night-20141017_081818-20141017_092258
# ...

# %%
print(tweetsMap["key"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-32f6dc30a629> in <module>
# ----> 1 print(tweetsMap["key"])
#
# KeyError: 'key'

# %%
rating_processing(r"C:\Users\eric4\Desktop\University\Research\Data\CREDBANK\cred_event_TurkRatings.data", r"C:\Users\eric4\Desktop\University\Research\Data\CREDBANK\outputTweets.json")
# Out:
# Inserting ratings for everything_royals_rain-20141015_161647-20141015_172214
# everything_royals_rain-20141015_161647-20141015_172214 is missing.
# Inserting ratings for host_patrick_neil-20141015_161647-20141015_172214
# Success
# Inserting mean for host_patrick_neil-20141015_161647-20141015_172214
# host_patrick_neil-20141015_161647-20141015_172214 is missing.
# Inserting ratings for royals_game_series-20141015_203526-20141015_213926
# Success
# Inserting mean for royals_game_series-20141015_203526-20141015_213926
# royals_game_series-20141015_203526-20141015_213926 is missing.
# Inserting ratings for giants_game_win-20141015_230140-20141016_000502
# Success
# Inserting mean for giants_game_win-20141015_230140-20141016_000502
# giants_game_win-20141015_230140-20141016_000502 is missing.
# Inserting ratings for october_ebola_house-20141015_230140-20141016_000502
# Success
# Inserting mean for october_ebola_house-20141015_230140-20141016_000502
# ...

# %% [markdown]
# # PHEME Processing

# %%
for root, dirs, files in os.walk(r"C:\Users\eric4\Desktop\University\Research\Data\pheme-rumour-scheme-dataset"):
    print(root)
# Out:
# C:\Users\eric4\Desktop\University\Research\Data\pheme-rumour-scheme-dataset
# C:\Users\eric4\Desktop\University\Research\Data\pheme-rumour-scheme-dataset\annotations
# C:\Users\eric4\Desktop\University\Research\Data\pheme-rumour-scheme-dataset\threads
# C:\Users\eric4\Desktop\University\Research\Data\pheme-rumour-scheme-dataset\threads\de
# C:\Users\eric4\Desktop\University\Research\Data\pheme-rumour-scheme-dataset\threads\de\germanwings-crash
# C:\Users\eric4\Desktop\University\Research\Data\pheme-rumour-scheme-dataset\threads\de\germanwings-crash\580319406301020160
# C:\Users\eric4\Desktop\University\Research\Data\pheme-rumour-scheme-dataset\threads\de\germanwings-crash\580319406301020160\images
# C:\Users\eric4\Desktop\University\Research\Data\pheme-rumour-scheme-dataset\threads\de\germanwings-crash\580319406301020160\reactions
# C:\Users\eric4\Desktop\University\Research\Data\pheme-rumour-scheme-dataset\threads\de\germanwings-crash\580319406301020160\source-tweets
# ...

# %% [markdown]
# # Internet Argument Corpus Processing

# %%
dataset = load_dataset('createdebate', username="root", password="215395El")

# %%
disputed = []
for discussion in dataset:
    for post in discussion:
        if post.response_type == 'disputed':
            disputed.append(post.text)
# Out:
# On 1 of 63. Time remaining: 0:00:00. Time taken: 0:00:00
# On 63 of 63. Time remaining: 0:00:00. Time taken: 0:00:02

# %% [markdown]
# # Pre-set Feature Selection

# %% [markdown]
# # Evaluating Model Transfer
